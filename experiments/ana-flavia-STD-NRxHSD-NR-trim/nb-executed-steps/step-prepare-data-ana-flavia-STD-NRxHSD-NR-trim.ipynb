# %% [markdown]
# # Prepare data for Pipeline

# %% [markdown]
# ## Setup and settings

# %%
# Importing packages
import os
import yaml
import logging
import pandas as pd
from Bio.Seq import Seq
from qiime2 import Artifact, Visualization
from qiime2.plugins import demux
from qiime2.plugins.cutadapt.methods import trim_paired

# %% [markdown]
# ### Receiving the parameters
#
# The following cell can receive parameters using the [papermill](https://papermill.readthedocs.io/en/latest/) tool.

# %%
params_path = os.path.join('..', 'params', 'ana-flavia-superlactacao.yaml')
experiment_name = 'jenneffer-vs-01'
base_dir = os.path.join('/', 'home', 'lauro', 'nupeb', 'redemicro')
manifest_file = os.path.join(base_dir, 'data', 'raw', 'manifest', 'not-hist-vs-manifest.csv')
img_folder = os.path.abspath(os.path.join(base_dir, 'imgs'))
replace_files = False
trim = None

# %%
# Parameters
experiment_name = "ana-flavia-STD-NRxHSD-NR-trim"
base_dir = "/home/lauro/nupeb/rede-micro/redemicro-ana-flavia-nutri"
manifest_file = "/home/lauro/nupeb/rede-micro/redemicro-ana-flavia-nutri/data/raw/manifest/manifest-ana-flavia-STD-NRxHSD-NR.csv"
metadata_file = "/home/lauro/nupeb/rede-micro/redemicro-ana-flavia-nutri/data/raw/metadata/metadata-ana-flavia-STD-NRxHSD-NR.tsv"
class_col = "group-id"
classifier_file = (
    "/home/lauro/nupeb/16S_classifiers_qiime2/silva-138-99-nb-classifier.qza"
)
replace_files = False
phred = 20
trunc_f = 0
trunc_r = 0
overlap = 12
threads = 6
trim = {
    "overlap": 8,
    "forward_primer": "CCTACGGGRSGCAGCAG",
    "reverse_primer": "GGACTACHVGGGTWTCTAAT",
}

# %%
# Setting hardcoded parameters for development and debbuging
production = True
if not production:
    params_path = os.path.join('..', 'params', 'ana-flavia-hipotese-01')
    with open(params_path, 'r') as stream:
        params = yaml.safe_load(stream)
        experiment_name = params['experiment_name']
        base_dir = params['base_dir']
        manifest_file = params['manifest_file']
        replace_files = params['replace_files']

# %% [markdown]
# ### Defining names and paths

# %%
# new_manifest = '/home/lauro/nupeb/redemicro/data/raw/manifest/karina-manifest.csv'
# with open(manifest_file, 'r') as oldm, open(new_manifest, 'w') as newm:
#     header = 'sample-id,absolute-filepath,direction\n'
#     newm.write(header)
#     for line in oldm.readlines()[1:]:
#         sid, forward, reverse = line[:-1].split(',')
#         fline = ','.join((sid, forward, 'forward')) + '\n'
#         rline = ','.join((sid, reverse, 'reverse')) + '\n'
#         newm.write(fline)
#         newm.write(rline)

# %%
# Define the output folder path
out_dir = os.path.join(base_dir, 'experiments', experiment_name, 'qiime-artifacts')
img_folder = os.path.abspath(os.path.join(base_dir, 'experiments', experiment_name, 'imgs'))

# Create path if it not exist
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)
    print(f'New qiime-artifacts folder path created: {out_dir}')

# Create path if it not exist
if not os.path.isdir(img_folder):
    os.makedirs(img_folder)
    print(f'New img folder path created: {img_folder}')

# Define the output artifact full path
demux_file = os.path.join(out_dir, 'demux-paired.qza')
demux_view = os.path.join(out_dir, 'demux-paired.qzv')
demux_file_trim = os.path.join(out_dir, 'demux-paired-trim.qza')
demux_view_trim = os.path.join(out_dir, 'demux-paired-trim.qzv')
# Out:
# New qiime-artifacts folder path created: /home/lauro/nupeb/rede-micro/redemicro-ana-flavia-nutri/experiments/ana-flavia-STD-NRxHSD-NR-trim/qiime-artifacts
# New img folder path created: /home/lauro/nupeb/rede-micro/redemicro-ana-flavia-nutri/experiments/ana-flavia-STD-NRxHSD-NR-trim/imgs

# %% [markdown]
# ## Step execution
#
# This Step import all `fastq` files in a **QIIME2 Artifact** object and save it to a new `qza` file of `SampleData[PairedEndSequencesWithQuality]`

# %%
manifest_df = pd.read_csv(manifest_file)
n_directions = len(manifest_df['direction'].unique())
if n_directions == 1:
    d_type = 'SampleData[SequencesWithQuality]'
    v_type = 'SingleEndFastqManifestPhred33'
elif n_directions == 2:
    d_type = 'SampleData[PairedEndSequencesWithQuality]'
    v_type = 'PairedEndFastqManifestPhred33'
else:
    print(f'ERROR: invalid number of directions {n_directions}')

# %%
# If the demux file does not exist or if the old file will be replaced
if not os.path.isfile(demux_file) or replace_files:
    
    # Import data and create an artifact object
    artifact = Artifact.import_data(
        d_type, 
        manifest_file, 
        view_type=v_type)
    
    # Save the artifact object to a new qza file
    artifact.save(demux_file)

else:
    artifact = Artifact.load(demux_file)

# %%
if not os.path.isfile(demux_view) or replace_files: 
    # Generate e visualization of the Artifact
    demux_summary = demux.visualizers.summarize(artifact)

    # Save a new visualization file based on the qza file
    Visualization.save(demux_summary.visualization, filepath=demux_view)
    
    demux_view_obj = demux_summary.visualization
else:
    demux_view_obj = Visualization.load(demux_view)

# %% [markdown]
# ## Step report

# %%
print(demux_view_obj)
# Out:
# <visualization: Visualization uuid: 6fa595a3-aad6-413f-886f-d8fe05a36646>

# %%
# Render Visualization
demux_view_obj
# Out:
# <visualization: Visualization uuid: 6fa595a3-aad6-413f-886f-d8fe05a36646>

# %% [markdown]
# [cutadapt](https://docs.qiime2.org/2022.2/plugins/available/cutadapt/trim-paired/)
#
# We trim the forward primer and the reverse complement of the reverse primer from the forward reads. We trim the reverse primer and reverse complement of the forward primer from the reverse reads.

# %%
demux_file_trim = os.path.join(out_dir, 'demux-paired-trim.qza')
demux_view_trim = os.path.join(out_dir, 'demux-paired-trim.qzv')

if trim and (not os.path.isfile(demux_file_trim) or replace_files):
    forward_primer = [trim['forward_primer']] # ['CCTACGGGRSGCAGCAG']
    reverse_primer = [trim['reverse_primer']] # ['GGACTACHVGGGTWTCTAAT']
    forward_reverse_complement = [str(Seq(forward_primer[0]).reverse_complement())]
    reverse_reverse_complement = [str(Seq(reverse_primer[0]).reverse_complement())]

    res = trim_paired(
        demultiplexed_sequences=artifact,
        front_f=forward_primer,
        front_r=reverse_primer,
        adapter_f=reverse_reverse_complement,
        adapter_r=forward_reverse_complement,
        cores=threads,
        overlap=trim['overlap'],
        indels=False,
        match_read_wildcards=True,
        match_adapter_wildcards=True,
        error_rate=0.15,
        discard_untrimmed=True,
    ).trimmed_sequences

    demux.visualizers.summarize(res).visualization
    res.save(demux_file_trim)
    Visualization.save(demux.visualizers.summarize(res).visualization, filepath=demux_view_trim)
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The commands to be run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: cutadapt --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121685_0_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121685_1_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121685_0_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121685_1_L001_R2_001.fastq.gz
# This is cutadapt 3.5 with Python 3.8.12
# Command line parameters: --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121685_0_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121685_1_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121685_0_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121685_1_L001_R2_001.fastq.gz
# Processing reads on 6 cores in paired-end mode ...
# Finished in 3.87 s (15 µs/read; 3.94 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:            254,393
#   Read 1 with adapter:                 251,998 (99.1%)
#   Read 2 with adapter:                 248,860 (97.8%)
#
# == Read fate breakdown ==
# Pairs that were too short:                  10 (0.0%)
# Pairs discarded as untrimmed:            7,871 (3.1%)
# Pairs written (passing filters):       246,512 (96.9%)
#
# Total basepairs processed:   129,740,430 bp
#   Read 1:    77,589,865 bp
#   Read 2:    52,150,565 bp
# Total written (filtered):    114,920,232 bp (88.6%)
#   Read 1:    70,145,471 bp
#   Read 2:    44,774,761 bp
#
# === First read: Adapter 1 ===
#
# Sequence: ATTAGAWACCCBDGTAGTCC; Type: regular 3'; Length: 20; Trimmed: 128 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Bases preceding removed adapters:
#   A: 0.0%
#   C: 34.4%
#   G: 60.9%
#   T: 4.7%
#   none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	28	3.9	1	0 28
# 9	18	1.0	1	0 18
# 10	1	0.2	1	0 1
# 20	9	0.0	3	9
# 21	10	0.0	3	8 2
# 22	14	0.0	3	12 1 1
# 23	14	0.0	3	13 1
# 24	10	0.0	3	8 2
# 25	13	0.0	3	12 0 1
# 26	2	0.0	3	1 1
# 30	1	0.0	3	1
# 218	1	0.0	3	1
# 234	1	0.0	3	1
# 236	1	0.0	3	1
# 237	1	0.0	3	0 1
# 253	1	0.0	3	1
# 279	1	0.0	3	0 1
# 302	2	0.0	3	2
#
#
# === First read: Adapter 2 ===
#
# Sequence: CCTACGGGRSGCAGCAG; Type: regular 5'; Length: 17; Trimmed: 251870 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	4	3.9	1	3 1
# 9	5	1.0	1	3 2
# 10	3	0.2	1	2 1
# 11	4	0.1	1	1 3
# 12	7	0.0	1	6 1
# 13	7	0.0	1	5 2
# 14	20	0.0	2	13 2 5
# 15	11	0.0	2	8 2 1
# 16	18	0.0	2	5 7 6
# 17	152	0.0	2	82 43 27
# 18	39230	0.0	2	38482 722 26
# 19	45580	0.0	2	44776 764 40
# 20	46235	0.0	2	45407 794 34
# 21	41414	0.0	2	40682 694 38
# 22	42544	0.0	2	41795 719 30
# 23	36597	0.0	2	36001 585 11
# 24	35	0.0	2	29 2 4
# 25	2	0.0	2	2
# 47	2	0.0	2	2
#
#
# === Second read: Adapter 3 ===
#
# Sequence: CTGCTGCSYCCCGTAGG; Type: regular 3'; Length: 17; Trimmed: 25 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Bases preceding removed adapters:
#   A: 8.0%
#   C: 8.0%
#   G: 36.0%
#   T: 8.0%
#   none/other: 40.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 203	4	0.0	2	4
# 204	11	0.0	2	11
# 205	10	0.0	2	10
#
#
# === Second read: Adapter 4 ===
#
# Sequence: GGACTACHVGGGTWTCTAAT; Type: regular 5'; Length: 20; Trimmed: 248835 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	1	3.9	1	0 1
# 12	2	0.0	1	1 1
# 13	3	0.0	1	3
# 14	4	0.0	2	1 1 2
# 15	12	0.0	2	10 1 1
# 16	4	0.0	2	1 3
# 17	6	0.0	2	2 2 2
# 18	9	0.0	2	7 1 1
# 19	12	0.0	2	5 5 2
# 20	185	0.0	3	74 55 37 19
# 21	46670	0.0	3	44245 1778 427 220
# 22	44425	0.0	3	42188 1648 399 190
# 23	41247	0.0	3	38808 1831 381 227
# 24	41891	0.0	3	39553 1702 433 203
# 25	37932	0.0	3	35622 1661 436 213
# 26	36391	0.0	3	34102 1664 425 200
# 27	34	0.0	3	20 9 4 1
# 33	1	0.0	3	1
# 44	1	0.0	3	1
# 57	1	0.0	3	0 0 0 1
# 60	1	0.0	3	0 0 1
# 61	2	0.0	3	0 0 0 2
# 64	1	0.0	3	1
#
# Command: cutadapt --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121686_2_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121686_3_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121686_2_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121686_3_L001_R2_001.fastq.gz
#
# This is cutadapt 3.5 with Python 3.8.12
# Command line parameters: --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121686_2_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121686_3_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121686_2_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121686_3_L001_R2_001.fastq.gz
# Processing reads on 6 cores in paired-end mode ...
# Finished in 1.76 s (17 µs/read; 3.54 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:            103,905
#   Read 1 with adapter:                 102,946 (99.1%)
#   Read 2 with adapter:                 101,888 (98.1%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs discarded as untrimmed:            2,954 (2.8%)
# Pairs written (passing filters):       100,951 (97.2%)
#
# Total basepairs processed:    52,991,550 bp
#   Read 1:    31,691,025 bp
#   Read 2:    21,300,525 bp
# Total written (filtered):     47,063,687 bp (88.8%)
#   Read 1:    28,727,135 bp
#   Read 2:    18,336,552 bp
#
# === First read: Adapter 1 ===
#
# Sequence: ATTAGAWACCCBDGTAGTCC; Type: regular 3'; Length: 20; Trimmed: 42 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Bases preceding removed adapters:
#   A: 4.8%
#   C: 14.3%
#   G: 78.6%
#   T: 2.4%
#   none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	3	1.6	1	0 3
# 9	4	0.4	1	0 4
# 21	4	0.0	3	3 1
# 22	1	0.0	3	1
# 23	6	0.0	3	6
# 24	2	0.0	3	2
# 25	2	0.0	3	2
# 29	2	0.0	3	2
# 30	6	0.0	3	6
# 31	5	0.0	3	5
# 32	1	0.0	3	1
# 33	1	0.0	3	1
# 34	1	0.0	3	1
# 78	1	0.0	3	1
# 85	1	0.0	3	1
# 166	1	0.0	3	0 0 1
# 234	1	0.0	3	1
#
#
# === First read: Adapter 2 ===
#
# Sequence: CCTACGGGRSGCAGCAG; Type: regular 5'; Length: 17; Trimmed: 102904 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	1	1.6	1	1
# 9	2	0.4	1	2
# 10	1	0.1	1	1
# 11	6	0.0	1	5 1
# 12	2	0.0	1	1 1
# 14	9	0.0	2	8 1
# 15	5	0.0	2	4 1
# 16	5	0.0	2	2 0 3
# 17	56	0.0	2	32 18 6
# 18	16355	0.0	2	16066 273 16
# 19	18584	0.0	2	18252 317 15
# 20	19044	0.0	2	18741 292 11
# 21	16875	0.0	2	16611 250 14
# 22	17209	0.0	2	16927 266 16
# 23	14733	0.0	2	14532 197 4
# 24	14	0.0	2	12 1 1
# 40	1	0.0	2	1
# 44	1	0.0	2	1
# 51	1	0.0	2	1
#
#
# === Second read: Adapter 3 ===
#
# Sequence: CTGCTGCSYCCCGTAGG; Type: regular 3'; Length: 17; Trimmed: 3 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Bases preceding removed adapters:
#   A: 0.0%
#   C: 0.0%
#   G: 0.0%
#   T: 100.0%
#   none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 204	3	0.0	2	3
#
#
# === Second read: Adapter 4 ===
#
# Sequence: GGACTACHVGGGTWTCTAAT; Type: regular 5'; Length: 20; Trimmed: 101885 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	6	1.6	1	1 5
# 11	2	0.0	1	1 1
# 12	2	0.0	1	2
# 13	1	0.0	1	1
# 14	2	0.0	2	0 0 2
# 15	3	0.0	2	1 2
# 16	3	0.0	2	1 2
# 17	3	0.0	2	2 1
# 18	4	0.0	2	2 1 1
# 19	11	0.0	2	6 4 1
# 20	93	0.0	3	47 23 17 6
# 21	19021	0.0	3	18052 727 151 91
# 22	18364	0.0	3	17427 671 172 94
# 23	16633	0.0	3	15720 660 173 80
# 24	17334	0.0	3	16399 664 178 93
# 25	15483	0.0	3	14599 640 167 77
# 26	14896	0.0	3	14056 607 158 75
# 27	20	0.0	3	15 4 0 1
# 60	1	0.0	3	0 0 0 1
# 61	1	0.0	3	0 1
# 63	2	0.0	3	0 0 1 1
#
# Command: cutadapt --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121687_4_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121687_5_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121687_4_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121687_5_L001_R2_001.fastq.gz
#
# This is cutadapt 3.5 with Python 3.8.12
# Command line parameters: --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121687_4_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121687_5_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121687_4_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121687_5_L001_R2_001.fastq.gz
# Processing reads on 6 cores in paired-end mode ...
# Finished in 1.17 s (18 µs/read; 3.39 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             66,368
#   Read 1 with adapter:                  65,760 (99.1%)
#   Read 2 with adapter:                  64,834 (97.7%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   2 (0.0%)
# Pairs discarded as untrimmed:            2,121 (3.2%)
# Pairs written (passing filters):        64,245 (96.8%)
#
# Total basepairs processed:    33,847,680 bp
#   Read 1:    20,242,240 bp
#   Read 2:    13,605,440 bp
# Total written (filtered):     29,949,537 bp (88.5%)
#   Read 1:    18,280,890 bp
#   Read 2:    11,668,647 bp
#
# === First read: Adapter 1 ===
#
# Sequence: ATTAGAWACCCBDGTAGTCC; Type: regular 3'; Length: 20; Trimmed: 85 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Bases preceding removed adapters:
#   A: 0.0%
#   C: 63.5%
#   G: 36.5%
#   T: 0.0%
#   none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	25	1.0	1	1 24
# 9	29	0.3	1	0 29
# 21	2	0.0	3	2
# 22	4	0.0	3	3 1
# 23	4	0.0	3	3 1
# 24	3	0.0	3	3
# 25	5	0.0	3	5
# 29	2	0.0	3	2
# 31	1	0.0	3	1
# 32	2	0.0	3	2
# 33	2	0.0	3	2
# 34	4	0.0	3	3 1
# 278	1	0.0	3	1
# 284	1	0.0	3	0 1
#
#
# === First read: Adapter 2 ===
#
# Sequence: CCTACGGGRSGCAGCAG; Type: regular 5'; Length: 17; Trimmed: 65675 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 10	1	0.1	1	1
# 11	4	0.0	1	2 2
# 13	3	0.0	1	2 1
# 14	5	0.0	2	3 0 2
# 15	3	0.0	2	2 0 1
# 16	3	0.0	2	1 1 1
# 17	36	0.0	2	22 8 6
# 18	10073	0.0	2	9860 201 12
# 19	11875	0.0	2	11657 206 12
# 20	12063	0.0	2	11869 186 8
# 21	10903	0.0	2	10700 196 7
# 22	11233	0.0	2	11028 191 14
# 23	9462	0.0	2	9334 123 5
# 24	10	0.0	2	9 1
# 26	1	0.0	2	1
#
#
# === Second read: Adapter 3 ===
#
# Sequence: CTGCTGCSYCCCGTAGG; Type: regular 3'; Length: 17; Trimmed: 9 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Bases preceding removed adapters:
#   A: 0.0%
#   C: 33.3%
#   G: 33.3%
#   T: 11.1%
#   none/other: 22.2%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 9	1	0.3	1	0 1
# 203	3	0.0	2	3
# 204	3	0.0	2	3
# 205	2	0.0	2	2
#
#
# === Second read: Adapter 4 ===
#
# Sequence: GGACTACHVGGGTWTCTAAT; Type: regular 5'; Length: 20; Trimmed: 64825 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	1	1.0	1	0 1
# 12	1	0.0	1	1
# 14	1	0.0	2	0 1
# 15	5	0.0	2	4 1
# 16	1	0.0	2	1
# 17	4	0.0	2	1 2 1
# 19	5	0.0	2	3 0 2
# 20	36	0.0	3	16 12 3 5
# 21	12261	0.0	3	11652 454 107 48
# 22	11400	0.0	3	10779 446 117 58
# 23	10858	0.0	3	10214 496 100 48
# 24	10877	0.0	3	10220 473 117 67
# 25	9802	0.0	3	9211 432 102 57
# 26	9560	0.0	3	8923 475 116 46
# 27	11	0.0	3	7 2 1 1
# 28	1	0.0	3	0 0 1
# 53	1	0.0	3	0 0 0 1
#
# Command: cutadapt --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121691_6_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121691_7_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121691_6_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121691_7_L001_R2_001.fastq.gz
#
# This is cutadapt 3.5 with Python 3.8.12
# Command line parameters: --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121691_6_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121691_7_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121691_6_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121691_7_L001_R2_001.fastq.gz
# Processing reads on 6 cores in paired-end mode ...
# Finished in 3.48 s (16 µs/read; 3.86 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:            224,175
#   Read 1 with adapter:                 221,891 (99.0%)
#   Read 2 with adapter:                 219,776 (98.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   1 (0.0%)
# Pairs discarded as untrimmed:            6,634 (3.0%)
# Pairs written (passing filters):       217,540 (97.0%)
#
# Total basepairs processed:   114,329,250 bp
#   Read 1:    68,373,375 bp
#   Read 2:    45,955,875 bp
# Total written (filtered):    101,415,359 bp (88.7%)
#   Read 1:    61,901,589 bp
#   Read 2:    39,513,770 bp
#
# === First read: Adapter 1 ===
#
# Sequence: ATTAGAWACCCBDGTAGTCC; Type: regular 3'; Length: 20; Trimmed: 66 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Bases preceding removed adapters:
#   A: 0.0%
#   C: 4.5%
#   G: 92.4%
#   T: 3.0%
#   none/other: 0.0%
# WARNING:
#     The adapter is preceded by 'G' extremely often.
#     The provided adapter sequence could be incomplete at its 5' end.
#     Ignore this warning when trimming primers.
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	4	3.4	1	0 4
# 9	1	0.9	1	0 1
# 20	5	0.0	3	5
# 21	3	0.0	3	2 1
# 22	8	0.0	3	8
# 23	6	0.0	3	6
# 24	4	0.0	3	3 1
# 25	3	0.0	3	2 1
# 29	2	0.0	3	2
# 30	4	0.0	3	4
# 31	2	0.0	3	1 1
# 32	13	0.0	3	13
# 33	7	0.0	3	7
# 34	2	0.0	3	2
# 160	1	0.0	3	1
# 284	1	0.0	3	1
#
#
# === First read: Adapter 2 ===
#
# Sequence: CCTACGGGRSGCAGCAG; Type: regular 5'; Length: 17; Trimmed: 221825 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	1	3.4	1	1
# 9	5	0.9	1	4 1
# 10	3	0.2	1	1 2
# 11	6	0.1	1	5 1
# 12	4	0.0	1	0 4
# 13	4	0.0	1	2 2
# 14	10	0.0	2	7 2 1
# 15	9	0.0	2	5 3 1
# 16	16	0.0	2	7 2 7
# 17	98	0.0	2	51 30 17
# 18	34555	0.0	2	33935 600 20
# 19	39994	0.0	2	39193 777 24
# 20	40929	0.0	2	40215 689 25
# 21	36497	0.0	2	35864 599 34
# 22	37849	0.0	2	37222 599 28
# 23	31809	0.0	2	31328 468 13
# 24	28	0.0	2	21 5 2
# 27	2	0.0	2	1 1
# 29	2	0.0	2	2
# 31	1	0.0	2	1
# 33	1	0.0	2	1
# 52	1	0.0	2	1
# 234	1	0.0	2	1
#
#
# === Second read: Adapter 3 ===
#
# Sequence: CTGCTGCSYCCCGTAGG; Type: regular 3'; Length: 17; Trimmed: 5 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Bases preceding removed adapters:
#   A: 0.0%
#   C: 40.0%
#   G: 20.0%
#   T: 20.0%
#   none/other: 20.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 203	2	0.0	2	2
# 204	2	0.0	2	2
# 205	1	0.0	2	1
#
#
# === Second read: Adapter 4 ===
#
# Sequence: GGACTACHVGGGTWTCTAAT; Type: regular 5'; Length: 20; Trimmed: 219771 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 12	3	0.0	1	2 1
# 13	2	0.0	1	1 1
# 14	4	0.0	2	2 1 1
# 15	7	0.0	2	4 1 2
# 16	3	0.0	2	2 0 1
# 18	3	0.0	2	0 2 1
# 19	11	0.0	2	4 3 4
# 20	170	0.0	3	64 50 33 23
# 21	40830	0.0	3	38764 1534 352 180
# 22	39747	0.0	3	37770 1465 344 168
# 23	36360	0.0	3	34391 1449 347 173
# 24	36920	0.0	3	34925 1437 365 193
# 25	33615	0.0	3	31714 1412 323 166
# 26	32052	0.0	3	30279 1300 321 152
# 27	36	0.0	3	25 7 2 2
# 28	1	0.0	3	1
# 30	1	0.0	3	1
# 53	1	0.0	3	1
# 61	1	0.0	3	0 0 0 1
# 62	3	0.0	3	0 1 0 2
# 63	1	0.0	3	0 1
#
#
# WARNING:
#     One or more of your adapter sequences may be incomplete.
#     Please see the detailed output above.
#
# Command: cutadapt --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121692_8_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121692_9_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121692_8_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121692_9_L001_R2_001.fastq.gz
#
# This is cutadapt 3.5 with Python 3.8.12
# Command line parameters: --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121692_8_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121692_9_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121692_8_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121692_9_L001_R2_001.fastq.gz
# Processing reads on 6 cores in paired-end mode ...
# Finished in 1.32 s (16 µs/read; 3.65 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             80,216
#   Read 1 with adapter:                  79,416 (99.0%)
#   Read 2 with adapter:                  78,121 (97.4%)
#
# == Read fate breakdown ==
# Pairs that were too short:                  15 (0.0%)
# Pairs discarded as untrimmed:            2,870 (3.6%)
# Pairs written (passing filters):        77,331 (96.4%)
#
# Total basepairs processed:    40,910,160 bp
#   Read 1:    24,465,880 bp
#   Read 2:    16,444,280 bp
# Total written (filtered):     36,048,173 bp (88.1%)
#   Read 1:    22,004,584 bp
#   Read 2:    14,043,589 bp
#
# === First read: Adapter 1 ===
#
# Sequence: ATTAGAWACCCBDGTAGTCC; Type: regular 3'; Length: 20; Trimmed: 51 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Bases preceding removed adapters:
#   A: 0.0%
#   C: 43.1%
#   G: 54.9%
#   T: 2.0%
#   none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	7	1.2	1	0 7
# 9	16	0.3	1	0 16
# 20	5	0.0	3	5
# 21	3	0.0	3	3
# 22	4	0.0	3	4
# 23	6	0.0	3	6
# 25	5	0.0	3	3 2
# 30	2	0.0	3	2
# 31	1	0.0	3	1
# 32	1	0.0	3	1
# 276	1	0.0	3	1
#
#
# === First read: Adapter 2 ===
#
# Sequence: CCTACGGGRSGCAGCAG; Type: regular 5'; Length: 17; Trimmed: 79365 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	1	1.2	1	1
# 9	1	0.3	1	1
# 11	1	0.0	1	0 1
# 14	4	0.0	2	2 1 1
# 15	2	0.0	2	0 0 2
# 16	5	0.0	2	3 2
# 17	49	0.0	2	23 14 12
# 18	12232	0.0	2	12001 223 8
# 19	14292	0.0	2	14026 243 23
# 20	14527	0.0	2	14274 244 9
# 21	13220	0.0	2	13012 192 16
# 22	13560	0.0	2	13323 225 12
# 23	11464	0.0	2	11268 190 6
# 24	6	0.0	2	4 0 2
# 32	1	0.0	2	0 1
#
#
# === Second read: Adapter 3 ===
#
# Sequence: CTGCTGCSYCCCGTAGG; Type: regular 3'; Length: 17; Trimmed: 32 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Bases preceding removed adapters:
#   A: 6.2%
#   C: 9.4%
#   G: 15.6%
#   T: 21.9%
#   none/other: 46.9%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	1	1.2	1	0 1
# 203	4	0.0	2	3 1
# 204	12	0.0	2	11 1
# 205	15	0.0	2	15
#
#
# === Second read: Adapter 4 ===
#
# Sequence: GGACTACHVGGGTWTCTAAT; Type: regular 5'; Length: 20; Trimmed: 78089 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 12	1	0.0	1	1
# 13	2	0.0	1	2
# 14	2	0.0	2	0 2
# 15	2	0.0	2	2
# 18	2	0.0	2	2
# 19	2	0.0	2	0 0 2
# 20	61	0.0	3	30 20 7 4
# 21	14486	0.0	3	13728 573 112 73
# 22	13993	0.0	3	13253 515 152 73
# 23	13178	0.0	3	12470 521 114 73
# 24	13074	0.0	3	12441 482 99 52
# 25	11830	0.0	3	11187 474 99 70
# 26	11446	0.0	3	10833 439 122 52
# 27	5	0.0	3	3 1 1
# 46	1	0.0	3	1
# 52	1	0.0	3	0 0 0 1
# 58	1	0.0	3	0 0 0 1
# 62	2	0.0	3	0 0 1 1
#
# Command: cutadapt --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121693_10_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121693_11_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121693_10_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121693_11_L001_R2_001.fastq.gz
#
# This is cutadapt 3.5 with Python 3.8.12
# Command line parameters: --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121693_10_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121693_11_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121693_10_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121693_11_L001_R2_001.fastq.gz
# Processing reads on 6 cores in paired-end mode ...
# Finished in 2.51 s (15 µs/read; 3.93 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:            164,608
#   Read 1 with adapter:                 163,069 (99.1%)
#   Read 2 with adapter:                 161,335 (98.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   3 (0.0%)
# Pairs discarded as untrimmed:            4,763 (2.9%)
# Pairs written (passing filters):       159,842 (97.1%)
#
# Total basepairs processed:    83,950,080 bp
#   Read 1:    50,205,440 bp
#   Read 2:    33,744,640 bp
# Total written (filtered):     74,517,810 bp (88.8%)
#   Read 1:    45,483,954 bp
#   Read 2:    29,033,856 bp
#
# === First read: Adapter 1 ===
#
# Sequence: ATTAGAWACCCBDGTAGTCC; Type: regular 3'; Length: 20; Trimmed: 101 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Bases preceding removed adapters:
#   A: 0.0%
#   C: 82.2%
#   G: 17.8%
#   T: 0.0%
#   none/other: 0.0%
# WARNING:
#     The adapter is preceded by 'C' extremely often.
#     The provided adapter sequence could be incomplete at its 5' end.
#     Ignore this warning when trimming primers.
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	38	2.5	1	0 38
# 9	46	0.6	1	0 46
# 20	2	0.0	3	2
# 21	2	0.0	3	2
# 22	6	0.0	3	6
# 23	2	0.0	3	2
# 24	3	0.0	3	3
# 25	1	0.0	3	1
# 282	1	0.0	3	1
#
#
# === First read: Adapter 2 ===
#
# Sequence: CCTACGGGRSGCAGCAG; Type: regular 5'; Length: 17; Trimmed: 162968 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	1	2.5	1	1
# 9	3	0.6	1	3
# 10	2	0.2	1	2
# 12	3	0.0	1	2 1
# 14	6	0.0	2	4 1 1
# 15	13	0.0	2	8 1 4
# 16	12	0.0	2	5 5 2
# 17	77	0.0	2	40 25 12
# 18	25475	0.0	2	25001 454 20
# 19	29054	0.0	2	28509 510 35
# 20	29775	0.0	2	29239 501 35
# 21	27186	0.0	2	26720 442 24
# 22	27872	0.0	2	27381 473 18
# 23	23465	0.0	2	23095 359 11
# 24	22	0.0	2	19 1 2
# 32	2	0.0	2	2
#
#
# === Second read: Adapter 3 ===
#
# Sequence: CTGCTGCSYCCCGTAGG; Type: regular 3'; Length: 17; Trimmed: 6 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Bases preceding removed adapters:
#   A: 16.7%
#   C: 16.7%
#   G: 16.7%
#   T: 0.0%
#   none/other: 50.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 9	1	0.6	1	0 1
# 203	1	0.0	2	1
# 204	1	0.0	2	1
# 205	3	0.0	2	3
#
#
# === Second read: Adapter 4 ===
#
# Sequence: GGACTACHVGGGTWTCTAAT; Type: regular 5'; Length: 20; Trimmed: 161329 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 10	1	0.2	1	0 1
# 12	2	0.0	1	1 1
# 14	2	0.0	2	1 0 1
# 15	10	0.0	2	8 0 2
# 16	4	0.0	2	2 1 1
# 17	3	0.0	2	2 1
# 18	2	0.0	2	1 0 1
# 19	4	0.0	2	1 1 2
# 20	128	0.0	3	49 31 29 19
# 21	30124	0.0	3	28677 1045 264 138
# 22	28918	0.0	3	27458 1096 238 126
# 23	26678	0.0	3	25231 1045 269 133
# 24	27385	0.0	3	26023 989 236 137
# 25	24389	0.0	3	22983 1008 254 144
# 26	23645	0.0	3	22323 957 272 93
# 27	28	0.0	3	20 3 4 1
# 38	1	0.0	3	1
# 59	1	0.0	3	0 0 1
# 62	3	0.0	3	0 0 1 2
# 65	1	0.0	3	0 0 0 1
#
#
# WARNING:
#     One or more of your adapter sequences may be incomplete.
#     Please see the detailed output above.
#
# Command: cutadapt --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121703_12_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121703_13_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121703_12_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121703_13_L001_R2_001.fastq.gz
#
# This is cutadapt 3.5 with Python 3.8.12
# Command line parameters: --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121703_12_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121703_13_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121703_12_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121703_13_L001_R2_001.fastq.gz
# Processing reads on 6 cores in paired-end mode ...
# Finished in 0.57 s (24 µs/read; 2.55 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             24,189
#   Read 1 with adapter:                  23,955 (99.0%)
#   Read 2 with adapter:                  23,066 (95.4%)
#
# == Read fate breakdown ==
# Pairs that were too short:                  14 (0.1%)
# Pairs discarded as untrimmed:            1,339 (5.5%)
# Pairs written (passing filters):        22,836 (94.4%)
#
# Total basepairs processed:    12,336,390 bp
#   Read 1:     7,377,645 bp
#   Read 2:     4,958,745 bp
# Total written (filtered):     10,633,459 bp (86.2%)
#   Read 1:     6,488,861 bp
#   Read 2:     4,144,598 bp
#
# === First read: Adapter 1 ===
#
# Sequence: ATTAGAWACCCBDGTAGTCC; Type: regular 3'; Length: 20; Trimmed: 56 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Bases preceding removed adapters:
#   A: 0.0%
#   C: 44.6%
#   G: 51.8%
#   T: 3.6%
#   none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	5	0.4	1	0 5
# 9	4	0.1	1	0 4
# 21	1	0.0	3	1
# 23	2	0.0	3	2
# 24	3	0.0	3	3
# 29	1	0.0	3	1
# 32	2	0.0	3	2
# 33	1	0.0	3	1
# 245	2	0.0	3	2
# 246	3	0.0	3	1 2
# 247	3	0.0	3	3
# 248	5	0.0	3	5
# 249	3	0.0	3	2 0 1
# 250	1	0.0	3	1
# 282	4	0.0	3	4
# 283	2	0.0	3	2
# 284	4	0.0	3	4
# 285	5	0.0	3	5
# 286	2	0.0	3	2
# 287	3	0.0	3	3
#
#
# === First read: Adapter 2 ===
#
# Sequence: CCTACGGGRSGCAGCAG; Type: regular 5'; Length: 17; Trimmed: 23899 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 10	1	0.0	1	1
# 15	1	0.0	2	0 1
# 16	2	0.0	2	1 1
# 17	7	0.0	2	4 1 2
# 18	3680	0.0	2	3610 63 7
# 19	4202	0.0	2	4120 78 4
# 20	4407	0.0	2	4323 81 3
# 21	3980	0.0	2	3912 61 7
# 22	4140	0.0	2	4052 85 3
# 23	3476	0.0	2	3432 44
# 24	2	0.0	2	1 0 1
# 28	1	0.0	2	1
#
#
# === Second read: Adapter 3 ===
#
# Sequence: CTGCTGCSYCCCGTAGG; Type: regular 3'; Length: 17; Trimmed: 33 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Bases preceding removed adapters:
#   A: 3.0%
#   C: 9.1%
#   G: 27.3%
#   T: 18.2%
#   none/other: 42.4%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 203	5	0.0	2	4 1
# 204	14	0.0	2	14
# 205	14	0.0	2	13 1
#
#
# === Second read: Adapter 4 ===
#
# Sequence: GGACTACHVGGGTWTCTAAT; Type: regular 5'; Length: 20; Trimmed: 23033 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 12	1	0.0	1	1
# 13	1	0.0	1	0 1
# 17	1	0.0	2	0 0 1
# 18	1	0.0	2	1
# 19	1	0.0	2	1
# 20	20	0.0	3	10 4 3 3
# 21	4309	0.0	3	4101 147 39 22
# 22	4174	0.0	3	3941 164 44 25
# 23	3791	0.0	3	3556 170 43 22
# 24	3843	0.0	3	3609 158 47 29
# 25	3575	0.0	3	3363 147 40 25
# 26	3304	0.0	3	3097 150 33 24
# 27	8	0.0	3	4 3 1
# 43	1	0.0	3	1
# 61	2	0.0	3	0 0 0 2
# 62	1	0.0	3	0 0 1
#
# Command: cutadapt --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121704_14_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121704_15_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121704_14_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121704_15_L001_R2_001.fastq.gz
#
# This is cutadapt 3.5 with Python 3.8.12
# Command line parameters: --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121704_14_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121704_15_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121704_14_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121704_15_L001_R2_001.fastq.gz
# Processing reads on 6 cores in paired-end mode ...
# Finished in 0.41 s (74 µs/read; 0.81 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:              5,549
#   Read 1 with adapter:                   5,499 (99.1%)
#   Read 2 with adapter:                   5,356 (96.5%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs discarded as untrimmed:              240 (4.3%)
# Pairs written (passing filters):         5,309 (95.7%)
#
# Total basepairs processed:     2,829,990 bp
#   Read 1:     1,692,445 bp
#   Read 2:     1,137,545 bp
# Total written (filtered):      2,474,084 bp (87.4%)
#   Read 1:     1,510,232 bp
#   Read 2:       963,852 bp
#
# === First read: Adapter 1 ===
#
# Sequence: ATTAGAWACCCBDGTAGTCC; Type: regular 3'; Length: 20; Trimmed: 4 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Bases preceding removed adapters:
#   A: 0.0%
#   C: 100.0%
#   G: 0.0%
#   T: 0.0%
#   none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	1	0.1	1	0 1
# 9	1	0.0	1	0 1
# 279	1	0.0	3	1
# 283	1	0.0	3	1
#
#
# === First read: Adapter 2 ===
#
# Sequence: CCTACGGGRSGCAGCAG; Type: regular 5'; Length: 17; Trimmed: 5495 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 17	4	0.0	2	3 1
# 18	880	0.0	2	858 22
# 19	985	0.0	2	966 19
# 20	1025	0.0	2	1009 13 3
# 21	879	0.0	2	860 19
# 22	914	0.0	2	903 10 1
# 23	808	0.0	2	796 10 2
#
#
# === Second read: Adapter 3 ===
#
# Sequence: CTGCTGCSYCCCGTAGG; Type: regular 3'; Length: 17; Trimmed: 3 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Bases preceding removed adapters:
#   A: 0.0%
#   C: 66.7%
#   G: 0.0%
#   T: 33.3%
#   none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 203	3	0.0	2	3
#
#
# === Second read: Adapter 4 ===
#
# Sequence: GGACTACHVGGGTWTCTAAT; Type: regular 5'; Length: 20; Trimmed: 5353 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 15	1	0.0	2	1
# 18	2	0.0	2	1 0 1
# 20	4	0.0	3	2 1 1
# 21	1027	0.0	3	964 42 13 8
# 22	925	0.0	3	871 35 10 9
# 23	888	0.0	3	837 37 8 6
# 24	903	0.0	3	857 33 5 8
# 25	850	0.0	3	780 36 21 13
# 26	752	0.0	3	702 28 15 7
# 62	1	0.0	3	0 0 1
#
# Command: cutadapt --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121705_16_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121705_17_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121705_16_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121705_17_L001_R2_001.fastq.gz
#
# This is cutadapt 3.5 with Python 3.8.12
# Command line parameters: --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121705_16_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121705_17_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121705_16_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121705_17_L001_R2_001.fastq.gz
# Processing reads on 6 cores in paired-end mode ...
# Finished in 4.98 s (14 µs/read; 4.15 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:            344,337
#   Read 1 with adapter:                 340,922 (99.0%)
#   Read 2 with adapter:                 337,158 (97.9%)
#
# == Read fate breakdown ==
# Pairs that were too short:                  12 (0.0%)
# Pairs discarded as untrimmed:           10,517 (3.1%)
# Pairs written (passing filters):       333,808 (96.9%)
#
# Total basepairs processed:   175,611,870 bp
#   Read 1:   105,022,785 bp
#   Read 2:    70,589,085 bp
# Total written (filtered):    155,616,970 bp (88.6%)
#   Read 1:    94,986,971 bp
#   Read 2:    60,629,999 bp
#
# === First read: Adapter 1 ===
#
# Sequence: ATTAGAWACCCBDGTAGTCC; Type: regular 3'; Length: 20; Trimmed: 43 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Bases preceding removed adapters:
#   A: 0.0%
#   C: 32.6%
#   G: 67.4%
#   T: 0.0%
#   none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	7	5.3	1	0 7
# 9	7	1.3	1	0 7
# 20	2	0.0	3	2
# 21	7	0.0	3	6 1
# 22	7	0.0	3	6 0 1
# 23	1	0.0	3	1
# 24	2	0.0	3	2
# 25	4	0.0	3	4
# 26	1	0.0	3	1
# 166	1	0.0	3	1
# 169	2	0.0	3	2
# 236	1	0.0	3	1
# 237	1	0.0	3	1
#
#
# === First read: Adapter 2 ===
#
# Sequence: CCTACGGGRSGCAGCAG; Type: regular 5'; Length: 17; Trimmed: 340879 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	1	5.3	1	1
# 9	4	1.3	1	4
# 10	9	0.3	1	8 1
# 11	10	0.1	1	7 3
# 12	6	0.0	1	6
# 13	10	0.0	1	6 4
# 14	30	0.0	2	19 7 4
# 15	16	0.0	2	7 4 5
# 16	24	0.0	2	15 6 3
# 17	199	0.0	2	102 57 40
# 18	53126	0.0	2	52172 916 38
# 19	61651	0.0	2	60490 1088 73
# 20	62544	0.0	2	61451 1030 63
# 21	56263	0.0	2	55262 938 63
# 22	57693	0.0	2	56689 936 68
# 23	49232	0.0	2	48452 763 17
# 24	57	0.0	2	43 5 9
# 26	1	0.0	2	1
# 34	1	0.0	2	0 1
# 45	1	0.0	2	1
# 63	1	0.0	2	1
#
#
# === Second read: Adapter 3 ===
#
# Sequence: CTGCTGCSYCCCGTAGG; Type: regular 3'; Length: 17; Trimmed: 26 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Bases preceding removed adapters:
#   A: 3.8%
#   C: 15.4%
#   G: 23.1%
#   T: 11.5%
#   none/other: 46.2%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	1	5.3	1	0 1
# 203	7	0.0	2	7
# 204	6	0.0	2	6
# 205	12	0.0	2	12
#
#
# === Second read: Adapter 4 ===
#
# Sequence: GGACTACHVGGGTWTCTAAT; Type: regular 5'; Length: 20; Trimmed: 337132 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 11	2	0.1	1	1 1
# 13	1	0.0	1	0 1
# 14	6	0.0	2	4 2
# 15	14	0.0	2	10 3 1
# 16	2	0.0	2	1 0 1
# 17	7	0.0	2	3 2 2
# 18	9	0.0	2	4 1 4
# 19	20	0.0	2	10 4 6
# 20	252	0.0	3	99 68 45 40
# 21	62962	0.0	3	59575 2455 647 285
# 22	60384	0.0	3	57160 2384 549 291
# 23	55799	0.0	3	52497 2376 601 325
# 24	56809	0.0	3	53427 2402 666 314
# 25	51187	0.0	3	48103 2189 587 308
# 26	49591	0.0	3	46434 2273 594 290
# 27	52	0.0	3	40 8 4
# 28	2	0.0	3	2
# 32	1	0.0	3	0 0 1
# 33	1	0.0	3	0 0 1
# 35	1	0.0	3	0 0 1
# 36	1	0.0	3	1
# 52	1	0.0	3	0 0 0 1
# 56	1	0.0	3	0 0 1
# 57	2	0.0	3	0 0 0 2
# 58	1	0.0	3	0 0 0 1
# 59	2	0.0	3	0 0 2
# 60	1	0.0	3	0 0 0 1
# 61	5	0.0	3	1 0 0 4
# 62	4	0.0	3	0 0 3 1
# 63	4	0.0	3	0 1 2 1
# 64	3	0.0	3	0 0 0 3
# 65	2	0.0	3	0 0 1 1
# 66	2	0.0	3	0 0 0 2
# 67	1	0.0	3	0 0 1
#
# Command: cutadapt --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121706_18_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121706_19_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121706_18_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121706_19_L001_R2_001.fastq.gz
#
# This is cutadapt 3.5 with Python 3.8.12
# Command line parameters: --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121706_18_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121706_19_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121706_18_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121706_19_L001_R2_001.fastq.gz
# Processing reads on 6 cores in paired-end mode ...
# Finished in 6.05 s (15 µs/read; 4.13 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:            416,322
#   Read 1 with adapter:                 412,332 (99.0%)
#   Read 2 with adapter:                 407,730 (97.9%)
#
# == Read fate breakdown ==
# Pairs that were too short:                  21 (0.0%)
# Pairs discarded as untrimmed:           12,483 (3.0%)
# Pairs written (passing filters):       403,818 (97.0%)
#
# Total basepairs processed:   212,324,220 bp
#   Read 1:   126,978,210 bp
#   Read 2:    85,346,010 bp
# Total written (filtered):    188,257,614 bp (88.7%)
#   Read 1:   114,910,144 bp
#   Read 2:    73,347,470 bp
#
# === First read: Adapter 1 ===
#
# Sequence: ATTAGAWACCCBDGTAGTCC; Type: regular 3'; Length: 20; Trimmed: 75 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Bases preceding removed adapters:
#   A: 0.0%
#   C: 40.0%
#   G: 54.7%
#   T: 5.3%
#   none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	19	6.4	1	0 19
# 9	15	1.6	1	0 15
# 18	1	0.0	2	1
# 20	3	0.0	3	3
# 21	7	0.0	3	5 1 1
# 22	5	0.0	3	5
# 23	7	0.0	3	6 1
# 24	9	0.0	3	7 2
# 25	3	0.0	3	3
# 26	4	0.0	3	2 0 2
# 84	1	0.0	3	1
# 282	1	0.0	3	1
#
#
# === First read: Adapter 2 ===
#
# Sequence: CCTACGGGRSGCAGCAG; Type: regular 5'; Length: 17; Trimmed: 412257 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	5	6.4	1	4 1
# 9	3	1.6	1	2 1
# 10	5	0.4	1	3 2
# 11	8	0.1	1	5 3
# 12	7	0.0	1	4 3
# 13	8	0.0	1	3 5
# 14	27	0.0	2	17 7 3
# 15	21	0.0	2	12 1 8
# 16	35	0.0	2	26 7 2
# 17	183	0.0	2	108 52 23
# 18	64944	0.0	2	63727 1168 49
# 19	73895	0.0	2	72605 1226 64
# 20	75810	0.0	2	74487 1261 62
# 21	67970	0.0	2	66807 1096 67
# 22	69866	0.0	2	68669 1144 53
# 23	59387	0.0	2	58482 880 25
# 24	81	0.0	2	63 6 12
# 25	2	0.0	2	2
#
#
# === Second read: Adapter 3 ===
#
# Sequence: CTGCTGCSYCCCGTAGG; Type: regular 3'; Length: 17; Trimmed: 37 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Bases preceding removed adapters:
#   A: 0.0%
#   C: 16.2%
#   G: 18.9%
#   T: 8.1%
#   none/other: 56.8%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 10	1	0.4	1	0 1
# 61	1	0.0	2	0 0 1
# 203	7	0.0	2	6 1
# 204	7	0.0	2	7
# 205	21	0.0	2	20 1
#
#
# === Second read: Adapter 4 ===
#
# Sequence: GGACTACHVGGGTWTCTAAT; Type: regular 5'; Length: 20; Trimmed: 407693 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	1	6.4	1	0 1
# 11	1	0.1	1	1
# 12	7	0.0	1	5 2
# 13	3	0.0	1	0 3
# 14	3	0.0	2	1 1 1
# 15	22	0.0	2	12 3 7
# 16	6	0.0	2	1 1 4
# 17	11	0.0	2	7 2 2
# 18	15	0.0	2	8 5 2
# 19	17	0.0	2	9 5 3
# 20	328	0.0	3	138 84 57 49
# 21	75920	0.0	3	72215 2693 651 361
# 22	73065	0.0	3	69374 2679 661 351
# 23	67778	0.0	3	63845 2911 692 330
# 24	69099	0.0	3	65324 2732 710 333
# 25	62151	0.0	3	58672 2553 622 304
# 26	59158	0.0	3	55823 2417 622 296
# 27	63	0.0	3	51 5 4 3
# 28	2	0.0	3	2
# 30	1	0.0	3	0 0 1
# 36	1	0.0	3	0 1
# 55	1	0.0	3	0 0 1
# 57	1	0.0	3	0 0 0 1
# 58	4	0.0	3	0 2 0 2
# 59	2	0.0	3	0 0 0 2
# 60	3	0.0	3	0 0 1 2
# 61	6	0.0	3	0 0 4 2
# 62	10	0.0	3	1 0 3 6
# 63	2	0.0	3	0 1 0 1
# 64	7	0.0	3	0 0 3 4
# 65	2	0.0	3	0 0 1 1
# 66	3	0.0	3	0 0 1 2
#
# Command: cutadapt --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121707_20_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121707_21_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121707_20_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121707_21_L001_R2_001.fastq.gz
#
# This is cutadapt 3.5 with Python 3.8.12
# Command line parameters: --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121707_20_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121707_21_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121707_20_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121707_21_L001_R2_001.fastq.gz
# Processing reads on 6 cores in paired-end mode ...
# Finished in 1.37 s (17 µs/read; 3.58 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             81,485
#   Read 1 with adapter:                  80,768 (99.1%)
#   Read 2 with adapter:                  79,421 (97.5%)
#
# == Read fate breakdown ==
# Pairs that were too short:                  10 (0.0%)
# Pairs discarded as untrimmed:            2,761 (3.4%)
# Pairs written (passing filters):        78,714 (96.6%)
#
# Total basepairs processed:    41,557,350 bp
#   Read 1:    24,852,925 bp
#   Read 2:    16,704,425 bp
# Total written (filtered):     36,688,578 bp (88.3%)
#   Read 1:    22,394,693 bp
#   Read 2:    14,293,885 bp
#
# === First read: Adapter 1 ===
#
# Sequence: ATTAGAWACCCBDGTAGTCC; Type: regular 3'; Length: 20; Trimmed: 38 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Bases preceding removed adapters:
#   A: 47.4%
#   C: 10.5%
#   G: 39.5%
#   T: 2.6%
#   none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	3	1.2	1	0 3
# 9	1	0.3	1	0 1
# 20	1	0.0	3	1
# 21	1	0.0	3	1
# 24	1	0.0	3	1
# 29	4	0.0	3	2 2
# 30	3	0.0	3	3
# 32	1	0.0	3	1
# 33	1	0.0	3	1
# 34	1	0.0	3	1
# 192	5	0.0	3	4 1
# 193	3	0.0	3	3
# 194	1	0.0	3	1
# 195	4	0.0	3	4
# 196	3	0.0	3	3
# 197	2	0.0	3	2
# 215	1	0.0	3	0 0 1
# 277	1	0.0	3	0 0 1
# 287	1	0.0	3	1
#
#
# === First read: Adapter 2 ===
#
# Sequence: CCTACGGGRSGCAGCAG; Type: regular 5'; Length: 17; Trimmed: 80730 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 9	2	0.3	1	2
# 10	3	0.1	1	2 1
# 12	2	0.0	1	1 1
# 14	6	0.0	2	4 0 2
# 15	6	0.0	2	3 1 2
# 16	3	0.0	2	2 0 1
# 17	53	0.0	2	34 11 8
# 18	12514	0.0	2	12316 193 5
# 19	14571	0.0	2	14298 256 17
# 20	14675	0.0	2	14381 282 12
# 21	13350	0.0	2	13116 221 13
# 22	13670	0.0	2	13440 224 6
# 23	11864	0.0	2	11665 193 6
# 24	9	0.0	2	5 2 2
# 28	1	0.0	2	1
# 30	1	0.0	2	1
#
#
# === Second read: Adapter 3 ===
#
# Sequence: CTGCTGCSYCCCGTAGG; Type: regular 3'; Length: 17; Trimmed: 30 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Bases preceding removed adapters:
#   A: 3.3%
#   C: 30.0%
#   G: 20.0%
#   T: 13.3%
#   none/other: 33.3%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 203	10	0.0	2	10
# 204	10	0.0	2	10
# 205	10	0.0	2	10
#
#
# === Second read: Adapter 4 ===
#
# Sequence: GGACTACHVGGGTWTCTAAT; Type: regular 5'; Length: 20; Trimmed: 79391 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 10	2	0.1	1	2
# 11	1	0.0	1	0 1
# 12	1	0.0	1	0 1
# 13	1	0.0	1	0 1
# 14	2	0.0	2	1 1
# 15	3	0.0	2	1 1 1
# 16	1	0.0	2	0 1
# 17	2	0.0	2	1 0 1
# 18	1	0.0	2	0 1
# 19	5	0.0	2	2 0 3
# 20	60	0.0	3	25 16 12 7
# 21	14780	0.0	3	14012 563 143 62
# 22	14314	0.0	3	13493 614 137 70
# 23	13139	0.0	3	12382 556 145 56
# 24	13365	0.0	3	12641 534 116 74
# 25	11962	0.0	3	11252 504 134 72
# 26	11730	0.0	3	10983 546 143 58
# 27	12	0.0	3	8 2 1 1
# 50	1	0.0	3	0 0 0 1
# 53	1	0.0	3	1
# 55	1	0.0	3	0 0 0 1
# 61	2	0.0	3	0 0 0 2
# 63	3	0.0	3	0 0 1 2
# 64	2	0.0	3	0 0 2
#
# Command: cutadapt --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121708_22_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121708_23_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121708_22_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121708_23_L001_R2_001.fastq.gz
#
# This is cutadapt 3.5 with Python 3.8.12
# Command line parameters: --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121708_22_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121708_23_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121708_22_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121708_23_L001_R2_001.fastq.gz
# Processing reads on 6 cores in paired-end mode ...
# Finished in 0.64 s (24 µs/read; 2.55 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             27,196
#   Read 1 with adapter:                  26,931 (99.0%)
#   Read 2 with adapter:                  26,035 (95.7%)
#
# == Read fate breakdown ==
# Pairs that were too short:                  18 (0.1%)
# Pairs discarded as untrimmed:            1,407 (5.2%)
# Pairs written (passing filters):        25,771 (94.8%)
#
# Total basepairs processed:    13,869,960 bp
#   Read 1:     8,294,780 bp
#   Read 2:     5,575,180 bp
# Total written (filtered):     12,010,229 bp (86.6%)
#   Read 1:     7,333,324 bp
#   Read 2:     4,676,905 bp
#
# === First read: Adapter 1 ===
#
# Sequence: ATTAGAWACCCBDGTAGTCC; Type: regular 3'; Length: 20; Trimmed: 12 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Bases preceding removed adapters:
#   A: 0.0%
#   C: 33.3%
#   G: 58.3%
#   T: 0.0%
#   none/other: 8.3%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	2	0.4	1	0 2
# 9	2	0.1	1	0 2
# 30	1	0.0	3	1
# 31	1	0.0	3	1
# 32	2	0.0	3	2
# 33	1	0.0	3	1
# 254	1	0.0	3	1
# 257	1	0.0	3	1
# 305	1	0.0	3	1
#
#
# === First read: Adapter 2 ===
#
# Sequence: CCTACGGGRSGCAGCAG; Type: regular 5'; Length: 17; Trimmed: 26919 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 13	1	0.0	1	1
# 14	2	0.0	2	2
# 16	1	0.0	2	0 1
# 17	13	0.0	2	6 6 1
# 18	4224	0.0	2	4153 66 5
# 19	4838	0.0	2	4744 94
# 20	4950	0.0	2	4856 92 2
# 21	4449	0.0	2	4345 98 6
# 22	4550	0.0	2	4472 74 4
# 23	3887	0.0	2	3838 48 1
# 24	4	0.0	2	3 0 1
#
#
# === Second read: Adapter 3 ===
#
# Sequence: CTGCTGCSYCCCGTAGG; Type: regular 3'; Length: 17; Trimmed: 38 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Bases preceding removed adapters:
#   A: 5.3%
#   C: 13.2%
#   G: 28.9%
#   T: 7.9%
#   none/other: 44.7%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 203	10	0.0	2	9 1
# 204	11	0.0	2	11
# 205	17	0.0	2	13 3 1
#
#
# === Second read: Adapter 4 ===
#
# Sequence: GGACTACHVGGGTWTCTAAT; Type: regular 5'; Length: 20; Trimmed: 25997 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	1	0.0	2	1
# 20	14	0.0	3	5 5 2 2
# 21	4795	0.0	3	4531 193 46 25
# 22	4571	0.0	3	4333 178 41 19
# 23	4434	0.0	3	4146 200 57 31
# 24	4389	0.0	3	4150 182 40 17
# 25	3946	0.0	3	3714 164 39 29
# 26	3839	0.0	3	3599 164 55 21
# 27	4	0.0	3	1 0 3
# 28	1	0.0	3	1
# 54	1	0.0	3	0 0 0 1
# 61	1	0.0	3	0 0 1
# 64	1	0.0	3	0 0 1
#
# Command: cutadapt --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121709_24_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121709_25_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121709_24_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121709_25_L001_R2_001.fastq.gz
#
# This is cutadapt 3.5 with Python 3.8.12
# Command line parameters: --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121709_24_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121709_25_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121709_24_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121709_25_L001_R2_001.fastq.gz
# Processing reads on 6 cores in paired-end mode ...
# Finished in 0.72 s (22 µs/read; 2.75 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             32,857
#   Read 1 with adapter:                  32,525 (99.0%)
#   Read 2 with adapter:                  31,730 (96.6%)
#
# == Read fate breakdown ==
# Pairs that were too short:                  11 (0.0%)
# Pairs discarded as untrimmed:            1,442 (4.4%)
# Pairs written (passing filters):        31,404 (95.6%)
#
# Total basepairs processed:    16,757,070 bp
#   Read 1:    10,021,385 bp
#   Read 2:     6,735,685 bp
# Total written (filtered):     14,618,640 bp (87.2%)
#   Read 1:     8,915,974 bp
#   Read 2:     5,702,666 bp
#
# === First read: Adapter 1 ===
#
# Sequence: ATTAGAWACCCBDGTAGTCC; Type: regular 3'; Length: 20; Trimmed: 131 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Bases preceding removed adapters:
#   A: 44.3%
#   C: 6.9%
#   G: 48.1%
#   T: 0.8%
#   none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 21	1	0.0	3	0 1
# 24	1	0.0	3	1
# 25	1	0.0	3	1
# 29	1	0.0	3	1
# 30	4	0.0	3	4
# 31	4	0.0	3	4
# 32	8	0.0	3	7 1
# 33	2	0.0	3	2
# 34	1	0.0	3	1
# 151	2	0.0	3	2
# 153	3	0.0	3	3
# 182	2	0.0	3	2
# 183	2	0.0	3	2
# 184	1	0.0	3	0 1
# 187	4	0.0	3	4
# 188	1	0.0	3	1
# 189	1	0.0	3	1
# 190	1	0.0	3	1
# 191	1	0.0	3	1
# 192	9	0.0	3	9
# 193	7	0.0	3	7
# 194	5	0.0	3	5
# 195	5	0.0	3	5
# 196	8	0.0	3	8
# 197	9	0.0	3	9
# 198	2	0.0	3	2
# 215	2	0.0	3	2
# 216	2	0.0	3	1 0 1
# 217	8	0.0	3	8
# 218	8	0.0	3	8
# 219	11	0.0	3	11
# 220	5	0.0	3	5
# 265	1	0.0	3	0 1
# 266	1	0.0	3	1
# 270	2	0.0	3	2
# 276	2	0.0	3	2
# 278	1	0.0	3	1
# 280	1	0.0	3	1
# 281	1	0.0	3	1
#
#
# === First read: Adapter 2 ===
#
# Sequence: CCTACGGGRSGCAGCAG; Type: regular 5'; Length: 17; Trimmed: 32394 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 11	2	0.0	1	2
# 12	1	0.0	1	1
# 13	1	0.0	1	1
# 14	1	0.0	2	1
# 15	1	0.0	2	0 1
# 16	3	0.0	2	1 1 1
# 17	20	0.0	2	9 6 5
# 18	5045	0.0	2	4958 83 4
# 19	5807	0.0	2	5693 109 5
# 20	5921	0.0	2	5814 101 6
# 21	5289	0.0	2	5195 92 2
# 22	5568	0.0	2	5485 77 6
# 23	4729	0.0	2	4661 66 2
# 24	5	0.0	2	5
# 29	1	0.0	2	1
#
#
# === Second read: Adapter 3 ===
#
# Sequence: CTGCTGCSYCCCGTAGG; Type: regular 3'; Length: 17; Trimmed: 19 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Bases preceding removed adapters:
#   A: 0.0%
#   C: 15.8%
#   G: 21.1%
#   T: 5.3%
#   none/other: 57.9%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 92	1	0.0	2	1
# 144	1	0.0	2	1
# 203	1	0.0	2	1
# 204	5	0.0	2	4 1
# 205	11	0.0	2	10 1
#
#
# === Second read: Adapter 4 ===
#
# Sequence: GGACTACHVGGGTWTCTAAT; Type: regular 5'; Length: 20; Trimmed: 31711 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 11	1	0.0	1	1
# 15	4	0.0	2	2 2
# 19	1	0.0	2	1
# 20	24	0.0	3	12 4 5 3
# 21	5800	0.0	3	5470 241 58 31
# 22	5699	0.0	3	5373 232 61 33
# 23	5351	0.0	3	5010 245 58 38
# 24	5376	0.0	3	5115 196 43 22
# 25	4814	0.0	3	4536 206 55 17
# 26	4630	0.0	3	4354 207 42 27
# 27	5	0.0	3	2 2 0 1
# 63	2	0.0	3	0 0 0 2
# 64	2	0.0	3	0 1 0 1
# 65	1	0.0	3	0 0 0 1
# 66	1	0.0	3	0 1
#
# Command: cutadapt --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121710_26_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121710_27_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121710_26_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121710_27_L001_R2_001.fastq.gz
#
# This is cutadapt 3.5 with Python 3.8.12
# Command line parameters: --cores 6 --error-rate 0.15 --times 1 --overlap 8 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121710_26_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-z5kdrf1y/210421121710_27_L001_R2_001.fastq.gz --adapter ATTAGAWACCCBDGTAGTCC --front CCTACGGGRSGCAGCAG -A CTGCTGCSYCCCGTAGG -G GGACTACHVGGGTWTCTAAT --no-indels --match-read-wildcards --discard-untrimmed /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121710_26_L001_R1_001.fastq.gz /tmp/qiime2-archive-xpuveehl/399d6386-b73f-448c-a5a2-dc63a94a4515/data/210421121710_27_L001_R2_001.fastq.gz
# Processing reads on 6 cores in paired-end mode ...
# Finished in 0.32 s (65 µs/read; 0.92 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:              4,908
#   Read 1 with adapter:                   4,853 (98.9%)
#   Read 2 with adapter:                   4,578 (93.3%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   3 (0.1%)
# Pairs discarded as untrimmed:              377 (7.7%)
# Pairs written (passing filters):         4,528 (92.3%)
#
# Total basepairs processed:     2,503,080 bp
#   Read 1:     1,496,940 bp
#   Read 2:     1,006,140 bp
# Total written (filtered):      2,106,079 bp (84.1%)
#   Read 1:     1,284,585 bp
#   Read 2:       821,494 bp
#
# === First read: Adapter 1 ===
#
# Sequence: ATTAGAWACCCBDGTAGTCC; Type: regular 3'; Length: 20; Trimmed: 31 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Bases preceding removed adapters:
#   A: 3.2%
#   C: 25.8%
#   G: 58.1%
#   T: 12.9%
#   none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 9	1	0.0	1	0 1
# 21	1	0.0	3	1
# 22	1	0.0	3	1
# 30	1	0.0	3	1
# 31	1	0.0	3	1
# 32	5	0.0	3	5
# 33	5	0.0	3	5
# 34	1	0.0	3	1
# 132	1	0.0	3	1
# 194	1	0.0	3	1
# 210	1	0.0	3	0 0 1
# 274	1	0.0	3	1
# 279	1	0.0	3	1
# 281	6	0.0	3	5 1
# 283	2	0.0	3	2
# 284	2	0.0	3	2
#
#
# === First read: Adapter 2 ===
#
# Sequence: CCTACGGGRSGCAGCAG; Type: regular 5'; Length: 17; Trimmed: 4822 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 15	2	0.0	2	0 0 2
# 17	2	0.0	2	0 2
# 18	769	0.0	2	754 14 1
# 19	841	0.0	2	828 11 2
# 20	839	0.0	2	823 14 2
# 21	779	0.0	2	766 13
# 22	839	0.0	2	819 19 1
# 23	750	0.0	2	734 15 1
# 24	1	0.0	2	1
#
#
# === Second read: Adapter 3 ===
#
# Sequence: CTGCTGCSYCCCGTAGG; Type: regular 3'; Length: 17; Trimmed: 8 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-17 bp: 2
#
# Bases preceding removed adapters:
#   A: 0.0%
#   C: 12.5%
#   G: 25.0%
#   T: 25.0%
#   none/other: 37.5%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 203	1	0.0	2	1
# 204	4	0.0	2	3 1
# 205	3	0.0	2	3
#
#
# === Second read: Adapter 4 ===
#
# Sequence: GGACTACHVGGGTWTCTAAT; Type: regular 5'; Length: 20; Trimmed: 4570 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 15	1	0.0	2	1
# 20	6	0.0	3	2 3 0 1
# 21	864	0.0	3	819 30 12 3
# 22	809	0.0	3	759 31 13 6
# 23	717	0.0	3	673 31 6 7
# 24	814	0.0	3	752 44 12 6
# 25	686	0.0	3	638 33 6 9
# 26	671	0.0	3	613 38 13 7
# 51	1	0.0	3	0 1
# 64	1	0.0	3	0 0 0 1
