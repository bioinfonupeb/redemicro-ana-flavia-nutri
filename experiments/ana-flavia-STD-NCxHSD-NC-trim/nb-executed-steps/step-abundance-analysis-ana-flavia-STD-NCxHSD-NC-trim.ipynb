# %% [markdown]
# ### STEP : Diversity Analysis
#
#
#
# #### Example
#
# - [“Moving Pictures” tutorial](https://docs.qiime2.org/2022.8/tutorials/moving-pictures-usage/?highlight=ancom)
# - [Biostats ANCOM](http://scikit-bio.org/docs/0.4.2/generated/generated/skbio.stats.composition.ancom.html)
#
#
# #### Methods
# - [composition](https://docs.qiime2.org/2022.8/plugins/available/composition/)
# - [composition add_pseudocount](https://docs.qiime2.org/2022.8/plugins/available/composition/add-pseudocount/): Increment all counts in table by pseudocount.
# - [composition ancom](https://docs.qiime2.org/2022.8/plugins/available/composition/ancom/): Apply ANCOM to identify features that differ in abundance.

# %% [markdown]
# ## Setup and settings

# %%
# Importing packages
import os
import pandas as pd
from qiime2 import Artifact
from qiime2 import Visualization
from qiime2 import Metadata

from qiime2.plugins.composition.visualizers import ancom
from qiime2.plugins.composition.methods import add_pseudocount

from qiime2.plugins.feature_table.methods import filter_samples
from qiime2.plugins.feature_table.methods import filter_seqs

# %matplotlib inline

# %% [markdown]
# ### Receiving the parameters
#
# The following cell can receive parameters using the [papermill](https://papermill.readthedocs.io/en/latest/) tool.

# %%
metadata_file = '/home/lauro/nupeb/rede-micro/redemicro-miliane-nutri/data/raw/metadata/miliane-metadata-CxAC.tsv'
base_dir = os.path.join('/', 'home', 'lauro', 'nupeb', 'rede-micro', 'redemicro-miliane-nutri')
experiment_name = 'miliane-CxAC-trim'
class_col = 'group-id'
replace_files = False

# %%
# Parameters
PAPERMILL_INPUT_PATH = "nb-templates/step-abundance-analysis2.ipynb"
PAPERMILL_OUTPUT_PATH = "/home/lauro/nupeb/rede-micro/redemicro-ana-flavia-nutri/experiments/ana-flavia-STD-NCxHSD-NC-trim/nb-executed-steps/step-abundance-analysis-ana-flavia-STD-NCxHSD-NC-trim.ipynb"
experiment_name = "ana-flavia-STD-NCxHSD-NC-trim"
base_dir = "/home/lauro/nupeb/rede-micro/redemicro-ana-flavia-nutri"
manifest_file = "/home/lauro/nupeb/rede-micro/redemicro-ana-flavia-nutri/data/raw/manifest/manifest-ana-flavia-STD-NCxHSD-NC.csv"
metadata_file = "/home/lauro/nupeb/rede-micro/redemicro-ana-flavia-nutri/data/raw/metadata/metadata-ana-flavia-STD-NCxHSD-NC.tsv"
class_col = "group-id"
classifier_file = "/home/lauro/nupeb/rede-micro/models/silva-138-99-nb-classifier.qza"
top_n = 20
replace_files = False
trunc_f = 0
trunc_r = 0
overlap = 12
threads = 6
trim = {
    "overlap": 8,
    "forward_primer": "CCTACGGGRSGCAGCAG",
    "reverse_primer": "GGACTACHVGGGTWTCTAAT",
}

# %%
experiment_folder = os.path.abspath(os.path.join(base_dir, 'experiments', experiment_name))
img_folder = os.path.abspath(os.path.join(experiment_folder, 'imgs'))

# %% [markdown]
# ### Defining names, paths and flags

# %%
# QIIME2 Artifacts folder
qiime_folder = os.path.join(experiment_folder, 'qiime-artifacts')

# Input - DADA2 Artifacts
dada2_tabs_path = os.path.join(qiime_folder, 'dada2-tabs.qza')

# %% [markdown]
# ## Step execution
#
# ### Load input files
#
# This Step import the QIIME2 `FeatureTable[Frequency]` Artifact and the `Metadata` file.

# %%
#Load Metadata
metadata_qa = Metadata.load(metadata_file)

#Load FeatureTable[Frequency]
tabs = Artifact.load(dada2_tabs_path)

# Filter FeatureTable[Frequency | RelativeFrequency | PresenceAbsence | Composition] based on Metadata sample ID values
tabs = filter_samples(
    table=tabs,
    metadata=metadata_qa,
).filtered_table
# Out:
# {'min_frequency': 0, 'max_frequency': None, 'min_features': 0, 'max_features': None, 'metadata': Metadata
# --------
# 15 IDs x 3 columns
# sample-name: ColumnProperties(type='categorical')
# group-id:    ColumnProperties(type='categorical')
# group-desc:  ColumnProperties(type='categorical')
#
# Call to_dataframe() for a tabular representation., 'where': None, 'exclude_ids': False, 'filter_empty_features': True, 'table': 2732 x 74 <class 'biom.table.Table'> with 12512 nonzero entries (6% dense)}
# {'min_frequency': 0, 'max_frequency': None, 'min_features': 0, 'max_features': None, 'metadata': Metadata
# --------
# 15 IDs x 3 columns
# sample-name: ColumnProperties(type='categorical')
# group-id:    ColumnProperties(type='categorical')
# group-desc:  ColumnProperties(type='categorical')
#
# Call to_dataframe() for a tabular representation., 'where': None, 'exclude_ids': False, 'filter_empty_features': True, 'table': 2732 x 74 <class 'biom.table.Table'> with 12512 nonzero entries (6% dense)}

# %% [markdown]
# # ANCOM
#
# Apply Analysis of Composition of Microbiomes (ANCOM) to identify features
# that are differentially abundant across groups.
#
# - [composition add_pseudocount](https://docs.qiime2.org/2022.8/plugins/available/composition/add-pseudocount/): Increment all counts in table by pseudocount.
# - [composition ancom](https://docs.qiime2.org/2022.8/plugins/available/composition/ancom/): Apply ANCOM to identify features that differ in abundance.

# %%
# Select class column
column = metadata_qa.get_column(class_col)

# %%
# Create the pseudocount table
composition_tab = add_pseudocount(table = tabs).composition_table
# Out:
# {'pseudocount': 1, 'table': 1065 x 15 <class 'biom.table.Table'> with 2412 nonzero entries (15% dense)}
# {'pseudocount': 1, 'table': 1065 x 15 <class 'biom.table.Table'> with 2412 nonzero entries (15% dense)}

# %%
# Create visualizations for each parameter combination for the ANCOM  method.
transform_functions = ('sqrt', 'log', 'clr')
difference_functions = ('mean_difference', 'f_statistic')
for t in transform_functions:
    for d in difference_functions:
        print(f"Calculating ANCOM with: {t} {d}")
        try:
            ancom_viz = ancom(
                table = composition_tab, 
                metadata = column, 
                transform_function = t, 
                difference_function = d
            ).visualization
            view_name = os.path.join(qiime_folder, f'ancom-{t}-{d}.qzv')
            ancom_viz.save(view_name)
        except Exception as e:
            print(f"ERROR: Calculating ANCOM with: {t} {d}")
            print(e)
# Out:
# Calculating ANCOM with: sqrt mean_difference
# {'metadata': <CategoricalMetadataColumn name='group-id' id_count=15>, 'transform_function': 'sqrt', 'difference_function': 'mean_difference', 'table':                c688e3b1ada46ed57f5b7e7e0d56664f  \
# S210421121682                            7659.0
# S210421121683                            2756.0
# S210421121684                           51380.0
# S210421121688                             676.0
# S210421121689                             143.0
# S210421121690                              26.0
# S210421121694                             162.0
# S210421121695                           13954.0
# S210421121696                            9359.0
# S210421121697                             699.0
# S210421121698                               1.0
# S210421121699                              20.0
# S210421121700                              32.0
# S210421121701                              16.0
# S210421121702                               1.0
#
#                bc798de4a9acd3ff7ba51c244523be14  \
# S210421121682                            2183.0
# S210421121683                            4267.0
# S210421121684                           22877.0
# S210421121688                            5538.0
# S210421121689                             154.0
# S210421121690                              28.0
# S210421121694                            1098.0
# S210421121695                            5591.0
# S210421121696                            4172.0
# S210421121697                            1040.0
# S210421121698                               1.0
# S210421121699                               1.0
# S210421121700
0
# S210421121689                               1.0
# S210421121690                               1.0
# S210421121694                               1.0
# S210421121695                             126.0
# S210421121696                               1.0
# S210421121697                               8.0
# S210421121698                               1.0
# S210421121699                               1.0
# S210421121700                               1.0
# S210421121701                               1.0
# S210421121702                               1.0
#
#                26fb6a43293a39fa4463bc35a69457b2  \
# S210421121682                            3005.0
# S210421121683                            1169.0
# S210421121684                           11301.0
# S210421121688                            4143.0
# S210421121689                               1.0
# S210421121690                              23.0
# S210421121694                              98.0
# S210421121695                            6420.0
# S210421121696                             776.0
# S210421121697                             287.0
# S210421121698                               1.0
# S210421121699                               1.0
# S210421121700                               1.0
# S210421121701                               1.0
# S210421121702                               1.0
#
#                ff6880f38ac8c1569873d503a3d53c2a  ...  \
# S210421121682                            1491.0  ...
# S210421121683                            3179.0  ...
# S210421121684                            6986.0  ...
# S210421121688                            5515.0  ...
# S210421121689                            1600.0  ...
# S210421121690                            2149.0  ...
# S210421121694                              93.0  ...
# S210421121695                             389.0  ...
# S210421121696                            9594.0  ...
# S210421121697                            3687.0  ...
# S210421121698                              20.0  ...
# S210421121699                             176.0  ...
# S210421121700                               1.0  ...
# S210421121701                             530.0  ...
# S210421121702                             901.0  ...
#
#                b04a0490a129c127f42d638f1d244311  \
# S210421121682                               1.0
# S210421121683                               6.0
# S210421121684                               1.0
# S210421121688                               1.0
# S210421121689                               1.0
# S210421121690                               1.0
# S210421121694                               1.0
# S210421121695                               1.0
# S210421121696                               1.0
# S210421121697                               1.0
# S210421121698                               1.0
# S210421121699                               1.0
# S210421121700                               1.0
# S210421121701                               1.0
# S210421121702                               1.0
#
#                92b4e447b0a75681c774a3937097e507  \
# S210421121682                               1.0
# S210421121683                               1.0
# S210421121684                               1.0
# S210421121688                               1.0
# S210421121689                               1.0
# S210421121690                               1.0
# S210421121694                               1.0
# S210421121695                               6.0
# S210421121696                               1.0
# S210421121697                               1.0
# S210421121698                               1.0
# S210421121699                               1.0
# S210421121700                               1.0
# S210421121701                               1.0
# S210421121702                               1.0
#
#                4a3183be9eedc760bfa8e50978e6f336  \
# S210421121682                               1.0
# S210421121683                               1.0
# S210421121684                               1.0
# S210421121688                               1.0
# S210421121689                               1.0
# S210421121690                               1.0
# S210421121694                               1.0
# S210421121695                               1.0
# S210421121696                               1.0
# S210421121697                               1.0
# S210421121698                               6.0
# S210421121699                               1.0
# S210421121700                               1.0
# S210421121701                               1.0
# S210421121702                               1.0
#
#                52e06b241df3fb25979bff175764ddec  \
# S210421121682                               1.0
# S210421121683                               1.0
# S210421121684                               1.0
# S210421121688                               1.0
# S210421121689                               1.0
# S210421121690                               1.0
# S210421121694                               1.0
# S210421121695                               1.0
# S210421121696                               1.0
# S210421121697                               1.0
# S210421121698                               1.0
# S210421121699                               1.0
# S210421121700                               1.0
# S210421121701                               6.0
# S210421121702                               1.0
#
#                4aae247d7c1ffd223ae9534f6c90ab37  \
# S210421121682                               1.0
# S210421121683                               1.0
# S210421121684                               1.0
# S210421121688                               1.0
# S210421121689                               1.0
# S210421121690                               1.0
# S210421121694                               1.0
# S210421121695                               1.0
# S210421121696                               1.0
# S210421121697                               5.0
# S210421121698                               1.0
# S210421121699                               1.0
# S210421121700                               1.0
# S210421121701                               1.0
# S210421121702                               1.0
#
#                9ac36c793c81746f7ceb62eb52c28f84  \
# S210421121682                               1.0
# S210421121683                               4.0
# S210421121684                               1.0
# S210421121688                               1.0
# S210421121689                               1.0
# S210421121690                               1.0
# S210421121694                               1.0
# S210421121695                               1.0
# S210421121696                               1.0
# S210421121697                               1.0
# S210421121698                               1.0
# S210421121699                               1.0
# S210421121700                               1.0
# S210421121701                               1.0
# S210421121702                               1.0
#
#                6057aef6dab4646ff0d85b178caeacbf  \
# S210421121682                               1.0
# S210421121683                               1.0
# S210421121684                               4.0
# S210421121688                               1.0
# S210421121689                               1.0
# S210421121690                               1.0
# S210421121694                               1.0
# S210421121695                               1.0
# S210421121696                               1.0
# S210421121697                               1.0
# S210421121698                               1.0
# S210421121699                               1.0
# S210421121700                               1.0
# S210421121701                               1.0
# S210421121702                               1.0
#
#                f7e58e756631c1a36b6874618c3e81c8  \
# S210421121682                               1.0
# S210421121683                               1.0
# S210421121684                               1.0
# S210421121688                               1.0
# S210421121689                               1.0
# S210421121690                               1.0
# S210421121694                               1.0
# S210421121695                               1.0
# S210421121696                               4.0
# S210421121697                               1.0
# S210421121698                               1.0
# S210421121699                               1.0
# S210421121700                               1.0
# S210421121701                               1.0
# S210421121702                               1.0
#
#                4393f0be1354f7198d1969c44d34d44a  \
# S210421121682                               1.0
# S210421121683                               1.0
# S210421121684                               1.0
# S210421121688                               1.0
# S210421121689                               1.0
# S210421121690                               1.0
# S210421121694                               1.0
# S210421121695                               1.0
# S210421121696                               1.0
# S210421121697                               1.0
# S210421121698                               1.0
# S210421121699                               3.0
# S210421121700                               1.0
# S210421121701                               1.0
# S210421121702                               1.0
#
#                a86e1aaa4715133f8fa2c0f52e03e6d7
# S210421121682                               1.0
# S210421121683                               1.0
# S210421121684                               1.0
# S210421121688                               1.0
# S210421121689                               1.0
# S210421121690                               1.0
# S210421121694                               1.0
# S210421121695                               1.0
# S210421121696                               1.0
# S210421121697                               1.0
# S210421121698                               1.0
# S210421121699                               1.0
# S210421121700                               1.0
# S210421121701                               1.0
# S210421121702                               3.0
#
# [15 rows x 1065 columns]}
# /home/lauro/anaconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/scipy/stats/_stats_py.py:3659: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# Calculating ANCOM with: log mean_difference
# {'metadata': <CategoricalMetadataColumn name='group-id' id_count=15>, 'transform_function': 'log', 'difference_function': 'mean_difference', 'table':                c688e3b1ada46ed57f5b7e7e0d56664f  \
# S210421121682                            7659.0
# S210421121683                            2756.0
# S210421121684                           51380.0
# S210421121688                             676.0
# S210421121689                             143.0
# S210421121690                              26.0
# S210421121694                             162.0
# S210421121695                           13954.0
# S210421121696                            9359.0
# S210421121697                             699.0
# S210421121698                               1.0
# S210421121699                              20.0
# S210421121700                              32.0
# S210421121701                              16.0
# S210421121702                               1.0
#
#                bc798de4a9acd3ff7ba51c244523be14  \
# S210421121682                            2183.0
# S210421121683                            4267.0
# S210421121684                           22877.0
# S210421121688                            5538.0
# S210421121689                             154.0
# S210421121690                              28.0
# S210421121694                            1098.0
# S210421121695                            5591.0
# S210421121696                            4172.0
# S210421121697                            1040.0
# S210421121698                               1.0
# S210421121699                               1.0
# S210421121700                             364.0
# S210421121701                              42.0
# S210421121702                             112.0
#
#                fca5b1ccd94b107a3ddf3e99feaafb6f  \
# S210421121682                            4843.0
# S210421121683                            1911.0
# S210421121684                           20205.0
# S210421121688                            6310.0
# S210421121689                             134.0
# S210421121690                               1.0
# S210421121694                               1.0
# S210421121695
# S210421121700                               1.0
# S210421121701                               1.0
# S210421121702                               1.0
#
#                26fb6a43293a39fa4463bc35a69457b2  \
# S210421121682                            3005.0
# S210421121683                            1169.0
# S210421121684                           11301.0
# S210421121688                            4143.0
# S210421121689                               1.0
# S210421121690                              23.0
# S210421121694                              98.0
# S210421121695                            6420.0
# S210421121696                             776.0
# S210421121697                             287.0
# S210421121698                               1.0
# S210421121699                               1.0
# S210421121700                               1.0
# S210421121701                               1.0
# S210421121702                               1.0
#
#                ff6880f38ac8c1569873d503a3d53c2a  ...  \
# S210421121682                            1491.0  ...
# S210421121683                            3179.0  ...
# S210421121684                            6986.0  ...
# S210421121688                            5515.0  ...
# S210421121689                            1600.0  ...
# S210421121690                            2149.0  ...
# S210421121694                              93.0  ...
# S210421121695                             389.0  ...
# S210421121696                            9594.0  ...
# S210421121697                            3687.0  ...
# S210421121698                              20.0  ...
# S210421121699                             176.0  ...
# S210421121700                               1.0  ...
# S210421121701                             530.0  ...
# S210421121702                             901.0  ...
#
#                b04a0490a129c127f42d638f1d244311  \
# S210421121682                               1.0
# S210421121683                               6.0
# S210421121684                               1.0
# S210421121688                               1.0
# S210421121689                               1.0
# S210421121690                               1.0
# S210421121694                               1.0
# S210421121695                               1.0
# S210421121696                               1.0
# S210421121697                               1.0
# S210421121698                               1.0
# S210421121699                               1.0
# S210421121700                               1.0
# S210421121701                               1.0
# S210421121702                               1.0
#
#                92b4e447b0a75681c774a3937097e507  \
# S210421121682                               1.0
# S210421121683                               1.0
# S210421121684                               1.0
# S210421121688                               1.0
# S210421121689                               1.0
# S210421121690                               1.0
# S210421121694                               1.0
# S210421121695                               6.0
# S210421121696                               1.0
# S210421121697                               1.0
# S210421121698                               1.0
# S210421121699                               1.0
# S210421121700                               1.0
# S210421121701                               1.0
# S210421121702                               1.0
#
#                4a3183be9eedc760bfa8e50978e6f336  \
# S210421121682                               1.0
# S210421121683                               1.0
# S210421121684                               1.0
# S210421121688                               1.0
# S210421121689                               1.0
# S210421121690                               1.0
# S210421121694                               1.0
# S210421121695                               1.0
# S210421121696                               1.0
# S210421121697                               1.0
# S210421121698                               6.0
# S210421121699                               1.0
# S210421121700                               1.0
# S210421121701                               1.0
# S210421121702                               1.0
#
#                52e06b241df3fb25979bff175764ddec  \
# S210421121682                               1.0
# S210421121683                               1.0
# S210421121684                               1.0
# S210421121688                               1.0
# S210421121689                               1.0
# S210421121690                               1.0
# S210421121694                               1.0
# S210421121695                               1.0
# S210421121696                               1.0
# S210421121697                               1.0
# S210421121698                               1.0
# S210421121699                               1.0
# S210421121700                               1.0
# S210421121701                               6.0
# S210421121702                               1.0
#
#                4aae247d7c1ffd223ae9534f6c90ab37  \
# S210421121682                               1.0
# S210421121683                               1.0
# S210421121684                               1.0
# S210421121688                               1.0
# S210421121689                               1.0
# S210421121690                               1.0
# S210421121694                               1.0
# S210421121695                               1.0
# S210421121696                               1.0
# S210421121697                               5.0
# S210421121698                               1.0
# S210421121699                               1.0
# S210421121700                               1.0
# S210421121701                               1.0
# S210421121702                               1.0
#
#                9ac36c793c81746f7ceb62eb52c28f84  \
# S210421121682                               1.0
# S210421121683                               4.0
# S210421121684                               1.0
# S210421121688                               1.0
# S210421121689                               1.0
# S210421121690                               1.0
# S210421121694                               1.0
# S210421121695                               1.0
# S210421121696                               1.0
# S210421121697                               1.0
# S210421121698                               1.0
# S210421121699                               1.0
# S210421121700                               1.0
# S210421121701                               1.0
# S210421121702                               1.0
#
#                6057aef6dab4646ff0d85b178caeacbf  \
# S210421121682                               1.0
# S210421121683                               1.0
# S210421121684                               4.0
# S210421121688                               1.0
# S210421121689                               1.0
# S210421121690                               1.0
# S210421121694                               1.0
# S210421121695                               1.0
# S210421121696                               1.0
# S210421121697                               1.0
# S210421121698                               1.0
# S210421121699                               1.0
# S210421121700                               1.0
# S210421121701                               1.0
# S210421121702                               1.0
#
#                f7e58e756631c1a36b6874618c3e81c8  \
# S210421121682                               1.0
# S210421121683                               1.0
# S210421121684                               1.0
# S210421121688                               1.0
# S210421121689                               1.0
# S210421121690                               1.0
# S210421121694                               1.0
# S210421121695                               1.0
# S210421121696                               4.0
# S210421121697                               1.0
# S210421121698                               1.0
# S210421121699                               1.0
# S210421121700                               1.0
# S210421121701                               1.0
# S210421121702                               1.0
#
#                4393f0be1354f7198d1969c44d34d44a  \
# S210421121682                               1.0
# S210421121683                               1.0
# S210421121684                               1.0
# S210421121688                               1.0
# S210421121689                               1.0
# S210421121690                               1.0
# S210421121694                               1.0
# S210421121695                               1.0
# S210421121696                               1.0
# S210421121697                               1.0
# S210421121698                               1.0
# S210421121699                               3.0
# S210421121700                               1.0
# S210421121701                               1.0
# S210421121702                               1.0
#
#                a86e1aaa4715133f8fa2c0f52e03e6d7
# S210421121682                               1.0
# S210421121683                               1.0
# S210421121684                               1.0
# S210421121688                               1.0
# S210421121689                               1.0
# S210421121690                               1.0
# S210421121694                               1.0
# S210421121695                               1.0
# S210421121696                               1.0
# S210421121697                               1.0
# S210421121698                               1.0
# S210421121699                               1.0
# S210421121700                               1.0
# S210421121701                               1.0
# S210421121702                               3.0
#
# [15 rows x 1065 columns]}
# /home/lauro/anaconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/scipy/stats/_stats_py.py:3659: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <module>
#       6 print(f"Calculating ANCOM with: {t} {d}")
#       7 try:
# ----> 8     ancom_viz = ancom(
#       9         table = composition_tab,
#      10         metadata = column,
#      11         transform_function = t,
#      12         difference_function = d
#      13     ).visualization
#      14     view_name = os.path.join(qiime_folder, f'ancom-{t}-{d}.qzv')
#      15     ancom_viz.save(view_name)
#
# File <decorator-gen-209>:2, in ancom(table, metadata, transform_function, difference_function)
#
# File ~/anaconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/qiime2/sdk/action.py:247, in Action._bind.<locals>.bound_callable(*args, **kwargs)
#     244 # Execute
#     245 #callable_args['feat_ext__ngram_range'] = (7,7)
#     246 print(callable_args)
# --> 247 outputs = self._callable_executor_(scope, callable_args,
#     248                                    output_types, provenance)
#     250 if len(outputs) != len(self.signature.outputs):
#     251     raise ValueError(
#     252         "Number of callable outputs must match number of "
#     253         "outputs defined in signature: %d != %d" %
#     254         (len(outputs), len(self.signature.outputs)))
#
# File ~/anaconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/qiime2/sdk/action.py:457, in Visualizer._callable_executor_(self, scope, view_args, output_types, provenance)
#     452 def _callable_executor_(self, scope, view_args, output_types, provenance):
#     453     # TODO use qiime2.plugin.OutPath when it exists, and update visualizers
#     454     # to work with OutPath instead of str. Visualization._from_data_dir
#     455     # will also need to be updated to support OutPath instead of str.
#     456     with tempfile.TemporaryDirectory(prefix='qiime2-temp-') as temp_dir:
# --> 457         ret_val = self._callable(output_dir=temp_dir, **view_args)
#     458         if ret_val is not None:
#     459             raise TypeError(
#     460                 "Visualizer %r should not return anything. "
#     461                 "Received %r as a return value." % (self, ret_val))
#
# File ~/anaconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/q2_composition/_ancom.py:54, in ancom(output_dir, table, metadata, transform_function, difference_function)
#      49     missing_data_sids = ', '.join(sorted(missing_data_sids))
#      50     raise ValueError('Metadata column is missing values for the '
#      51                      'following samples. Values need to be added for '
#      52                      'these samples, or the samples need to be removed '
#      53                      'from the table: %s' % missing_data_sids)
# ---> 54 ancom_results = skbio_ancom(table,
#      55                             metadata.to_series(),
#      56                             significance_test=f_oneway)
#      57 ancom_results[0].sort_values(by='W', ascending=False, inplace=True)
#      58 ancom_results[0].rename(columns={'reject': 'Reject null hypothesis'},
#      59                         inplace=True)
#
# File ~/anaconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/skbio/stats/composition.py:1105, in ancom(table, grouping, alpha, tau, theta, multiple_comparisons_correction, significance_test, percentiles)
#    1100     raise ValueError('`table` index and `grouping` '
#    1101                      'index must be consistent.')
#    1103 n_feat = mat.shape[1]
# -> 1105 _logratio_mat = _log_compare(mat.values, cats.values, significance_test)
#    1106 logratio_mat = _logratio_mat + _logratio_mat.T
#    1108 # Multiple comparisons
#
# File ~/anaconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/skbio/stats/composition.py:1216, in _log_compare(mat, cats, significance_test)
#    1214 for i in range(c-1):
#    1215     ratio = (log_mat[:, i].T - log_mat[:, i+1:].T).T
# -> 1216     m, p = np.apply_along_axis(func,
#    1217                                axis=0,
#    1218                                arr=ratio)
#    1219     log_ratio[i, i+1:] = np.squeeze(np.array(p.T))
#    1220 return log_ratio
#
# File <__array_function__ internals>:180, in apply_along_axis(*args, **kwargs)
#
# File ~/anaconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/numpy/lib/shape_base.py:402, in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     400 buff[ind0] = res
#     401 for ind in inds:
# --> 402     buff[ind] = asanyarray(func1d(inarr_view[ind], *args, **kwargs))
#     404 if not isinstance(res, matrix):
#     405     # wrap the array, to preserve subclasses
#     406     buff = res.__array_wrap__(buff)
#
# File ~/anaconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/skbio/stats/composition.py:1212, in _log_compare.<locals>.func(x)
#    1211 def func(x):
# -> 1212     return significance_test(*[x[cats == k] for k in cs])
#
# File ~/anaconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/scipy/stats/_stats_py.py:3672, in f_oneway(axis, *args)
#    3669 offset = alldata.mean(axis=axis, keepdims=True)
#    3670 alldata -= offset
# -> 3672 normalized_ss = _square_of_sums(alldata, axis=axis) / bign
#    3674 sstot = _sum_of_squares(alldata, axis=axis) - normalized_ss
#    3676 ssbn = 0
#
# File ~/anaconda3/envs/qiime2-2022.2/lib/python3.8/site-packages/scipy/stats/_stats_py.py:8582, in _square_of_sums(a, axis)
#    8561 """Sum elements of the input array, and return the square(s) of that sum.
#    8562
#    8563 Parameters
#    (...)
#    8579
#    8580 """
#    8581 a, axis = _chk_asarray(a, axis)
# -> 8582 s = np.sum(a, axis)
#    8583 if not np.isscalar(s):
#    8584     return s.astype(float) * s
#
# File <__array_function__ internals>:181, in sum(*args, **kwargs)
#
# KeyboardInterrupt:
